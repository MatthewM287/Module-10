# %% [markdown]
# <a href="https://colab.research.google.com/github/MatthewM287/Module-10/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2. Data Science Is the act of understanding and getting information out of structured or unstructured piles of data

# %% [markdown]
# 3. The difference between a list and tuples is that tuples can *not* be changed while list can

# %% [markdown]
# 4.
#
# *   Skikitlearn: It gives you algorithims
# *   pandas: It helps anylize and manipulate data
# *   tensorflow: It does fast numerical computations
# *   numpy: Creates arrays and does math on those arrays
# *   tkinter: Creates GUI's
